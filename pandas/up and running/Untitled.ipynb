# %%
arr = [1,2,3,4]

# %%
print(arr)
# Out:
# [1, 2, 3, 4]

# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd

# %%
dic1 = {"Movie":['Lord of the Rings','Pulp Fiction','Fight club'],"Year":['2000','1994','1998']}
df1= pd.DataFrame(dic1)
df1
# Out:
#                Movie  Year
# 0  Lord of the Rings  2000
# 1       Pulp Fiction  1994
# 2         Fight club  1998

# %%
dic2 = {"Movie":['Goodfellas','Inception','Brittanny runs a Marathon'],"Year":['1992','2004','2017']}
df2= pd.DataFrame(dic2)
df_combined= pd.concat([df1,df2])
df_combined
# Out:
#                        Movie  Year
# 0          Lord of the Rings  2000
# 1               Pulp Fiction  1994
# 2                 Fight club  1998
# 0                 Goodfellas  1992
# 1                  Inception  2004
# 2  Brittanny runs a Marathon  2017
